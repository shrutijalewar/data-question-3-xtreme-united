# %%
import json
import requests
import urllib.request
import geopandas as gpd
from geopandas import GeoDataFrame
import pandas as pd
import fiona
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
from shapely.geometry import Point
import mplleaflet

# %%
response = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&minmagnitude=6.0&orderby=time&limit=1000')

# %%
print(response.status_code)
# Out:
# 200

# %%
live_eq = response.content

# %%
## API site: https://earthquake.usgs.gov/fdsnws/event/1/#format-geojson

url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&orderby=time&limit=1000'
request = requests.get(url)
b = bytes(request.content)
with fiona.BytesCollection(b) as f:
    crs = f.crs
    gdf = gpd.GeoDataFrame.from_features(f, crs=crs)
    print(gdf.head(20))
# Out:
#    alert  cdi      code                                             detail  \
# 0         0.0  37823175  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1         0.0  17464658  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2         0.0  72935231  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3         0.0  17464656  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4         0.0  72935221  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5         0.0  72935216  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 6         0.0  61996546  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 7         0.0  37823167  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 8         0.0  00614351  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9         0.0  17464398  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 10        0.0  72935206  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 11        0.0  1000bl7u  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 12        3.4  1000bl7t  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 13        0.0  17464366  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 14        0.0  71108034  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 15        0.0  72935196  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 16        0.0  1000bl7k  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 17        0.0  17463435  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 18        0.0  72935191  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 19        0.0  37823135  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt     gap                                           geometry  \
# 0   0.080610     0   52.00             POINT Z (-116.7911667 33.4983333 5.47)
# 1   0.000000     0    0.00                   POINT Z (-150.3879 61.5533 48.3)
# 2   0.009516     0   73.00              POINT Z (-122.828331 38.8079987 0.77)
# 3   0.000000     0    0.00                   POINT Z (-149.9497 62.3208 16.9)
# 4   0.005984     0   52.00             POINT Z (-122.776001 38.8180008 -0.36)
# 5   0.014730     0   78.00              POINT Z (-122.8209991 38.8046684 2.1)
# 6   0.000000     0  103.00  POINT Z (-155.3930054 19.2700005 9.52999999999...
# 7   0.022440     0  102.00                   POINT Z (-116.4485 33.5115 7.85)
# 8   0.203000     0  118.68                    POINT Z (-117.0204 37.1827 7.4)
# 9   0.000000     0    0.00                      POINT Z (-148.87 63.9868 3.5)
# 10  0.309600     0   77.00            POINT Z (-119.7528333 35.9506667 21.73)
# 11  0.171000     0   76.00             POINT Z (-98.55329999999999 36.5584 5)
# 12  8.467000     3   95.00                        POINT Z (28.915 -2.6393 10)
# 13  0.000000     0    0.00                      POINT Z (-148.7431 64.816 19)
# 14  0.002908     0  109.00                POINT Z (-122.7901667 38.7955 0.05)
# 15  0.005104     0  109.00  POINT Z (-122.7941667 38.7946667 -0.0700000000...
# 16  0.929000     0  172.00                  POINT Z (-172.7273 51.8905 32.66)
# 17  0.000000     0    0.00         POINT Z (-142.9357 65.28959999999999 15.5)
# 18  0.003009     0  125.00             POINT Z (-122.8389969 38.8398323 1.46)
# 19  0.060860     0   33.00               POINT Z (-116.2945 33.2433333 11.82)
#
#             id                      ids  \
# 0   ci37823175             ,ci37823175,
# 1   ak17464658             ,ak17464658,
# 2   nc72935231             ,nc72935231,
# 3   ak17464656             ,ak17464656,
# 4   nc72935221             ,nc72935221,
# 5   nc72935216             ,nc72935216,
# 6   hv61996546             ,hv61996546,
# 7   ci37823167             ,ci37823167,
# 8   nn00614351             ,nn00614351,
# 9   ak17464398             ,ak17464398,
# 10  nc72935206  ,nc72935206,us1000bl7w,
# 11  us1000bl7u             ,us1000bl7u,
# 12  us1000bl7t             ,us1000bl7t,
# 13  ak17464366             ,ak17464366,
# 14  nc71108034             ,nc71108034,
# 15  nc72935196             ,nc72935196,
# 16  us1000bl7k  ,ak17463437,us1000bl7k,
# 17  ak17463435  ,ak17463435,us1000bl7b,
# 18  nc72935191             ,nc72935191,
# 19  ci37823135             ,ci37823135,
#
#                           ...                          sources     status  \
# 0                         ...                             ,ci,  automatic
# 1                         ...                             ,ak,  automatic
# 2                         ...                             ,nc,  automatic
# 3                         ...                             ,ak,  automatic
# 4                         ...                             ,nc,  automatic
# 5                         ...                             ,nc,  automatic
# 6                         ...                             ,hv,  automatic
# 7                         ...                             ,ci,  automatic
# 8                         ...                             ,nn,   reviewed
# 9                         ...                             ,ak,  automatic
# 10                        ...                          ,nc,us,   reviewed
# 11                        ...                             ,us,   reviewed
# 12                        ...                             ,us,   reviewed
# 13                        ...                             ,ak,  automatic
# 14                        ...                             ,nc,   reviewed
# 15                        ...                             ,nc,   reviewed
# 16                        ...                          ,ak,us,   reviewed
# 17                        ...                          ,ak,us,  automatic
# 18                        ...                             ,nc,  automatic
# 19                        ...                             ,ci,   reviewed
#
#              time                                              title  tsunami  \
# 0   1512444237170                      M 0.6 - 9km NE of Aguanga, CA        0
# 1   1512443501559                 M 1.7 - 23km W of Big Lake, Alaska        0
# 2   1512443255770                 M 0.9 - 7km WNW of The Geysers, CA        0
# 3   1512441305436                 M 1.8 - 8km E of Talkeetna, Alaska        0
# 4   1512440597520                          M 1.9 - 5km W of Cobb, CA        0
# 5   1512439961790                 M 1.3 - 6km WNW of The Geysers, CA        0
# 6   1512438955060                  M 1.7 - 11km NE of Pahala, Hawaii        0
# 7   1512437329730                   M 0.4 - 21km SW of La Quinta, CA        0
# 8   1512436678956                  M 1.8 - 38km NW of Beatty, Nevada        0
# 9   1512435570444                  M 1.9 - 15km NNE of Healy, Alaska        0
# 10  1512434662990             M 3.0 - 20km ESE of Kettleman City, CA        0
# 11  1512433919090                 M 2.8 - 25km W of Helena, Oklahoma        0
# 12  1512433369700  M 4.6 - 15km SSE of Bukavu, Democratic Republi...        0
# 13  1512432375084           M 0.8 - 31km NNE of North Nenana, Alaska        0
# 14  1512431194950                  M 0.2 - 4km NW of The Geysers, CA        0
# 15  1512431186970                 M 0.3 - 4km WNW of The Geysers, CA        0
# 16  1512430645430                  M 4.3 - 106km ESE of Atka, Alaska        0
# 17  1512430260178                  M 2.6 - 79km SE of Circle, Alaska        0
# 18  1512430124930                 M 1.0 - 10km NW of The Geysers, CA        0
# 19  1512429830910               M 1.9 - 8km E of Borrego Springs, CA        0
#
#           type                                              types   tz  \
# 0   earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480
# 1   earthquake                                  ,geoserve,origin, -540
# 2   earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480
# 3   earthquake                                  ,geoserve,origin, -540
# 4   earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480
# 5   earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480
# 6   earthquake                       ,geoserve,origin,phase-data, -600
# 7   earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480
# 8   earthquake                       ,geoserve,origin,phase-data, -480
# 9   earthquake                                  ,geoserve,origin, -540
# 10  earthquake  ,focal-mechanism,geoserve,nearby-cities,origin... -480
# 11  earthquake                       ,geoserve,origin,phase-data, -360
# 12  earthquake                  ,dyfi,geoserve,origin,phase-data,  120
# 13  earthquake                                  ,geoserve,origin, -540
# 14  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480
# 15  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480
# 16  earthquake                       ,geoserve,origin,phase-data, -720
# 17  earthquake                       ,geoserve,origin,phase-data, -540
# 18  earthquake  ,geoserve,nearby-cities,origin,phase-data,scit... -480
# 19  earthquake  ,focal-mechanism,geoserve,nearby-cities,origin... -480
#
#           updated                                                url
# 0   1512444461985  https://earthquake.usgs.gov/earthquakes/eventp...
# 1   1512443848208  https://earthquake.usgs.gov/earthquakes/eventp...
# 2   1512444424206  https://earthquake.usgs.gov/earthquakes/eventp...
# 3   1512441542482  https://earthquake.usgs.gov/earthquakes/eventp...
# 4   1512441603962  https://earthquake.usgs.gov/earthquakes/eventp...
# 5   1512444482208  https://earthquake.usgs.gov/earthquakes/eventp...
# 6   1512439155120  https://earthquake.usgs.gov/earthquakes/eventp...
# 7   1512437542289  https://earthquake.usgs.gov/earthquakes/eventp...
# 8   1512439070188  https://earthquake.usgs.gov/earthquakes/eventp...
# 9   1512436247287  https://earthquake.usgs.gov/earthquakes/eventp...
# 10  1512444722280  https://earthquake.usgs.gov/earthquakes/eventp...
# 11  1512435164040  https://earthquake.usgs.gov/earthquakes/eventp...
# 12  1512434941639  https://earthquake.usgs.gov/earthquakes/eventp...
# 13  1512432692277  https://earthquake.usgs.gov/earthquakes/eventp...
# 14  1512444123197  https://earthquake.usgs.gov/earthquakes/eventp...
# 15  1512443463172  https://earthquake.usgs.gov/earthquakes/eventp...
# 16  1512432314040  https://earthquake.usgs.gov/earthquakes/eventp...
# 17  1512430861040  https://earthquake.usgs.gov/earthquakes/eventp...
# 18  1512431281845  https://earthquake.usgs.gov/earthquakes/eventp...
# 19  1512433207660  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [20 rows x 28 columns]

# %%
eq_df.to_csv('/Users/Justin/Code/data-question-3-xtreme-united/eq_api_return.csv')

# %%
pylab.rcParams['figure.figsize'] = 25, 25

eq_df.plot()
plt.show()

# %%
world = gpd.GeoDataFrame.from_file('/Users/Justin/Code/data-question-3-xtreme-united/world.shp')

# %%
# pylab.rcParams['figure.figsize'] = 25, 25
# base = world.plot(color='black', edgecolor='grey')

# eq_df.plot(ax=base, marker='o', column ='mag', cmap = 'autumn', markersize=7);

# %%
# plt.show()

# %%
top_eq = pd.DataFrame.from_csv('/Users/Justin/Code/data-question-3-xtreme-united/eq_df.csv')

# %%
top_eq.head()
# Out:
#              origin    country   lat   long depth_km  magnitude sec_effects  \
# 1  1900-05-11 17:23      Japan  38.7  141.1        5        7.0         NaN
# 2  1900-07-12 06:25     Turkey  40.3   43.1      NaN        5.9         NaN
# 3  1900-10-29 09:11  Venezuela  11.0  -66.0        0        7.7         NaN
# 4  1901-02-15 00:00      China  26.0  100.1        0        6.5         NaN
# 5  1901-03-31 07:11   Bulgaria  43.4   28.7      NaN        6.4         NaN
#
#    shaking_death  pde_total  utsu_total  em_total  other_deaths  deaths
# 1            NaN        NaN         NaN       NaN           NaN     NaN
# 2            NaN        NaN       140.0       NaN           NaN   140.0
# 3            NaN        NaN         NaN       NaN           NaN     NaN
# 4            NaN        NaN         NaN       NaN           NaN     NaN
# 5            NaN        NaN         4.0       NaN           NaN     4.0

# %%
geometry = [Point(xy) for xy in zip(top_eq.long, top_eq.lat)]
hist_eq_df = top_eq.drop(['long', 'lat'], axis=1)
crs = {'init': 'epsg:4326'}
gdf = GeoDataFrame(hist_eq_df, crs=crs, geometry=geometry)

# %%
hist_eq_df.head()
# Out:
#              origin    country depth_km  magnitude sec_effects  shaking_death  \
# 1  1900-05-11 17:23      Japan        5        7.0         NaN            NaN
# 2  1900-07-12 06:25     Turkey      NaN        5.9         NaN            NaN
# 3  1900-10-29 09:11  Venezuela        0        7.7         NaN            NaN
# 4  1901-02-15 00:00      China        0        6.5         NaN            NaN
# 5  1901-03-31 07:11   Bulgaria      NaN        6.4         NaN            NaN
#
#    pde_total  utsu_total  em_total  other_deaths  deaths            geometry
# 1        NaN         NaN       NaN           NaN     NaN  POINT (141.1 38.7)
# 2        NaN       140.0       NaN           NaN   140.0   POINT (43.1 40.3)
# 3        NaN         NaN       NaN           NaN     NaN      POINT (-66 11)
# 4        NaN         NaN       NaN           NaN     NaN    POINT (100.1 26)
# 5        NaN         4.0       NaN           NaN     4.0   POINT (28.7 43.4)

# %%
pylab.rcParams['figure.figsize'] = 25, 25
base = world.plot(color='black', edgecolor='grey')

eq_df.plot(ax=base, marker='o', column ='mag', cmap = 'autumn', markersize = 7);
# hist_eq_df.plot(ax=base, marker='*', color = 'blue', markersize = 10);
# ax.set_axis_off()
# f.suptitle('Last 1000 earthquakes with magnitude > 6')

mplleaflet.show()

# %%
eq_df.plot(marker='o', column ='mag', cmap = 'autumn', markersize = 10);
# hist_eq_df.plot(marker='*', color = 'blue', markersize = 10);
# ax.set_axis_off()
# f.suptitle('Last 1000 earthquakes with magnitude > 6')

mplleaflet.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-257-840254802a04> in <module>()
#       4 # f.suptitle('Last 1000 earthquakes with magnitude > 6')
#       5
# ----> 6 mplleaflet.show()
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/_display.py in show(fig, path, **kwargs)
#     178     fullpath = os.path.abspath(path)
#     179     with open(fullpath, 'w') as f:
# --> 180         save_html(fig, fileobj=f, **kwargs)
#     181     webbrowser.open('file://' + fullpath)
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/_display.py in save_html(fig, fileobj, **kwargs)
#     129     if not hasattr(fileobj, 'write'):
#     130         raise ValueError("fileobj should be a filename or a writable file")
# --> 131     html = fig_to_html(fig, **kwargs)
#     132     fileobj.write(html)
#     133     fileobj.close()
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/_display.py in fig_to_html(fig, template, tiles, crs, epsg, embed_links)
#      82     renderer = LeafletRenderer(crs=crs, epsg=epsg)
#      83     exporter = Exporter(renderer)
# ---> 84     exporter.run(fig)
#      85
#      86     attribution = _attribution + ' | ' + tiles[1]
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/mplexporter/exporter.py in run(self, fig)
#      49             import matplotlib.pyplot as plt
#      50             plt.close(fig)
# ---> 51         self.crawl_fig(fig)
#      52
#      53     @staticmethod
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/mplexporter/exporter.py in crawl_fig(self, fig)
#     116                                        props=utils.get_figure_properties(fig)):
#     117             for ax in fig.axes:
# --> 118                 self.crawl_ax(ax)
#     119
#     120     def crawl_ax(self, ax):
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/mplexporter/exporter.py in crawl_ax(self, ax)
#     147                 with self.renderer.draw_legend(legend=legend, props=props):
#     148                     if props['visible']:
# --> 149                         self.crawl_legend(ax, legend)
#     150
#     151     def crawl_legend(self, ax, legend):
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/mplexporter/exporter.py in crawl_legend(self, ax, legend)
#     163                 # What kind of object...
#     164                 if isinstance(child, matplotlib.patches.Patch):
# --> 165                     self.draw_patch(ax, child, force_trans=ax.transAxes)
#     166                 elif isinstance(child, matplotlib.text.Text):
#     167                     if not (child is legend.get_children()[-1]
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/mplexporter/exporter.py in draw_patch(self, ax, patch, force_trans)
#     225                                 pathcodes=pathcodes,
#     226                                 style=linestyle,
# --> 227                                 mplobj=patch)
#     228
#     229     def draw_collection(self, ax, collection,
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/leaflet_renderer.py in draw_path(self, data, coordinates, pathcodes, style, offset, offset_coordinates, mplobj)
#     123             else:
#     124                 data = [c.tolist() for c in data]
# --> 125             rings = list(iter_rings(data, pathcodes))
#     126
#     127             if style['facecolor'] != 'none':
#
# ~/anaconda3/lib/python3.6/site-packages/mplleaflet/utils.py in iter_rings(data, pathcodes)
#      12             ring.append(point)
#      13         else:
# ---> 14             raise ValueError('Unrecognized code: {}'.format(code))
#      15
#      16     if len(ring):
#
# ValueError: Unrecognized code: S
