# %%
import json
import requests
import fiona
import geopandas as gpd
import pandas as pd
from bokeh.io import output_file, show
from bokeh.models import GeoJSONDataSource
from bokeh.plotting import figure
from bokeh.sampledata.sample_geojson import geojson
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool
)

# %%
response = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&orderby=time&limit=1000')

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&orderby=time&limit=1000'
request = requests.get(url)
b = bytes(request.content)
with fiona.BytesCollection(b) as f:
    crs = f.crs
    gdf = gpd.GeoDataFrame.from_features(f, crs=crs)
    print(gdf.head(20))
# Out:
#    alert  cdi      code                                             detail  \
# 0         0.0  37823543  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1         0.0  17485495  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2         0.0  1000bmky  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3         0.0  00614432  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4         0.0  00614431  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5         0.0  37823535  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 6         0.0  37823527  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 7         0.0  00614421  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 8         0.0  72935566  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9         0.0  80273344  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 10        3.1  1000bmkc  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...

# %%
map_options = GMapOptions(lat=29.0209069, lng=-33.2748153, map_type="terrain", zoom=1)

plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options)
plot.title.text = "Earthquake Data"

source = 

plot.api_key = "AIzaSyDNq75Mq5-RyD9MkxI2SNqwDmTLcpt5nEc"

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
show(plot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-1f49c07ef4e3> in <module>()
#       4 plot.title.text = "Earthquake Data"
#       5
# ----> 6 geo_source = GeoJSONDataSource(geojson=gdf)
#       7
#       8 plot.api_key = "AIzaSyDNq75Mq5-RyD9MkxI2SNqwDmTLcpt5nEc"
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/model.py in __init__(self, **kwargs)
#     217         self._id = kwargs.pop("id", make_id())
#     218         self._document = None
# --> 219         super(Model, self).__init__(**kwargs)
#     220         default_theme.apply_to_model(self)
#     221
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/core/has_props.py in __init__(self, **properties)
#     234
#     235         for name, value in properties.items():
# --> 236             setattr(self, name, value)
#     237
#     238     def __setattr__(self, name, value):
#
# ...

# %%
est_dam = pd.read_csv('/Users/Justin/Code/data-question-3-xtreme-united/est_damage.csv')

# %%
est_dam = pd.DataFrame(est_dam)

# %%
est_dam = pd.melt(est_dam, id_vars = ['Country name'])
